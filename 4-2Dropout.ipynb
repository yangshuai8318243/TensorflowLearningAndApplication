# %%
import numpy as np
import tensorflow as tf;
import matplotlib.pylab as plt;

import tensorflow.examples.tutorials.mnist.input_data as input_data 
# 载入数据
mnist = input_data.read_data_sets("MNIST_data",one_hot = True)

# 每个批次的大小
batch_size = 200;
# 计算一共有多少批次
n_batch = mnist.train.num_examples // batch_size;

# 定义图片的站位数据
x = tf.placeholder(tf.float32,[None,784])
y = tf.placeholder(tf.float32,[None,10])

# 创建神经网络
# W = tf.Variable(tf.zeros([784,10]))
# b = tf.Variable(tf.zeros([10]))

keep_prob = tf.placeholder(tf.float32)


# 初始化优化
W1 = tf.Variable(tf.truncated_normal([784,2000],stddev = 0.1))
b1 = tf.Variable(tf.zeros([2000])+0.1)
Wx_plus_b_L1 = tf.matmul(x,W1) + b1;
L1 = tf.tanh(Wx_plus_b_L1)
L1_drop = tf.nn.dropout(L1,keep_prob)

W2 = tf.Variable(tf.truncated_normal([2000,2000],stddev = 0.1))
b2 = tf.Variable(tf.zeros([2000])+0.1)
Wx_plus_b_L2 = tf.matmul(L1_drop,W2) + b2;
L2 = tf.tanh(Wx_plus_b_L2)
L2_drop = tf.nn.dropout(L2,keep_prob)

W3 = tf.Variable(tf.truncated_normal([2000,1000],stddev = 0.1))
b3 = tf.Variable(tf.zeros([1000])+0.1)
Wx_plus_b_L3 = tf.matmul(L2_drop,W3) + b3;
L3 = tf.tanh(Wx_plus_b_L3)
L3_drop = tf.nn.dropout(L3,keep_prob)

W4 = tf.Variable(tf.truncated_normal([1000,10],stddev = 0.1))
b4 = tf.Variable(tf.zeros([10])+0.1)
Wx_plus_b_L4 = tf.matmul(L3_drop,W4) + b4;
perdiction = tf.tanh(Wx_plus_b_L4)

# 定义二次函数 代价函数
# loss = tf.reduce_mean(tf.square(y-perdiction))
# 交叉熵优化
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(labels=y,logits = perdiction))


# 使用梯度下降
# train_setp = tf.train.GradientDescentOptimizer(0.22).minimize(loss)
train_setp = tf.train.AdadeltaOptimizer().minimize(loss)

init = tf.global_variables_initializer()

# 将返回最大的值放在一个一维张量中
correct_prediction = tf.equal(tf.argmax(y,1),tf.argmax(perdiction,1))
# 测试准确率
accuracy = tf.reduce_mean(tf.cast(correct_prediction,tf.float32))

with tf.Session() as sess:
    sess.run(init)
    for epoch in range(50):
        for batch in range(n_batch):
            batch_xs,batch_ys = mnist.train.next_batch(batch_size);
            sess.run(train_setp,feed_dict={x:batch_xs,y:batch_ys,keep_prob:1.0})
            
            
        test_acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels,keep_prob:1.0})
        
        train_acc = sess.run(accuracy,feed_dict={x:mnist.train.images,y:mnist.train.labels,keep_prob:1.0})
        
        print("Iter" + str(epoch) + ",Testing Acc"+ str(test_acc) + " Train acc:"+str(train_acc))
# Out:
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# Iter0,Testing Acc0.9433 Train acc:0.95254546
# Iter1,Testing Acc0.9595 Train acc:0.9720909
# Iter2,Testing Acc0.9629 Train acc:0.9807818
# Iter3,Testing Acc0.9682 Train acc:0.98483634
# Iter4,Testing Acc0.9681 Train acc:0.9872364
# Iter5,Testing Acc0.9703 Train acc:0.98867273
# Iter6,Testing Acc0.9719 Train acc:0.98956364
# Iter7,Testing Acc0.9715 Train acc:0.99036366
# Iter8,Testing Acc0.9714 Train acc:0.9908
# Iter9,Testing Acc0.9715 Train acc:0.99094546
# Iter10,Testing Acc0.9721 Train acc:0.99127275
# Iter11,Testing Acc0.9721 Train acc:0.9914909
# Iter12,Testing Acc0.972 Train acc:0.9917455
# Iter13,Testing Acc0.9724 Train acc:0.9918182
# Iter14,Testing Acc0.9722 Train acc:0.9919818
# Iter15,Testing Acc0.9729 Train acc:0.9920545
# Iter16,Testing Acc0.9726 Train acc:0.9922
# Iter17,Testing Acc0.9722 Train acc:0.99227273
# Iter18,Testing Acc0.973 Train acc:0.9924
# Iter19,Testing Acc0.9727 Train acc:0.99256366
# Iter20,Testing Acc0.9727 Train acc:0.99258184
# Iter21,Testing Acc0.973 Train acc:0.9926182
# Iter22,Testing Acc0.9723 Train acc:0.9927273
# Iter23,Testing Acc0.9726 Train acc:0.9927818
# Iter24,Testing Acc0.9729 Train acc:0.9928182
# Iter25,Testing Acc0.973 Train acc:0.9928727
# Iter26,Testing Acc0.9728 Train acc:0.9929818
# Iter27,Testing Acc0.9724 Train acc:0.993
# Iter28,Testing Acc0.973 Train acc:0.9930909
# Iter29,Testing Acc0.973 Train acc:0.9930909
# Iter30,Testing Acc0.9736 Train acc:0.99314547
# Iter31,Testing Acc0.9735 Train acc:0.9931273
# Iter32,Testing Acc0.9736 Train acc:0.9931091
# Iter33,Testing Acc0.9737 Train acc:0.99323636
# Iter34,Testing Acc0.9736 Train acc:0.99323636
# Iter35,Testing Acc0.9735 Train acc:0.9932727
# Iter36,Testing Acc0.9735 Train acc:0.9933636
# Iter37,Testing Acc0.9742 Train acc:0.9933818
# Iter38,Testing Acc0.9741 Train acc:0.9934545
# Iter39,Testing Acc0.9734 Train acc:0.99347275
# Iter40,Testing Acc0.9737 Train acc:0.99356365
# Iter41,Testing Acc0.9738 Train acc:0.99358183
# Iter42,Testing Acc0.9736 Train acc:0.99363637
# Iter43,Testing Acc0.9737 Train acc:0.9936182
# Iter44,Testing Acc0.9739 Train acc:0.99365455
# Iter45,Testing Acc0.974 Train acc:0.9936727
# Iter46,Testing Acc0.974 Train acc:0.99365455
# Iter47,Testing Acc0.9739 Train acc:0.99372727
# Iter48,Testing Acc0.9734 Train acc:0.9937091
# Iter49,Testing Acc0.9737 Train acc:0.9937636
